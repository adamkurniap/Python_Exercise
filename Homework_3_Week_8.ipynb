# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a07f1448-619d-44b8-a736-01f4db5d98b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a07f1448-619d-44b8-a736-01f4db5d98b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance.csv

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %% [markdown]
# #Nomor 1

# %%
df.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %% [markdown]
# #Nomor 2

# %%
stats.pearsonr(df['math score'], df['reading score'])
# Out:
# (0.8175796636720539, 1.7877531099062402e-241)

# %%
stats.pearsonr(df['math score'], df['writing score'])
# Out:
# (0.8026420459498078, 3.3760270425694173e-226)

# %%
stats.pearsonr(df['reading score'], df['writing score'])
# Out:
# (0.9545980771462479, 0.0)

# %% [markdown]
# #Nomor 3

# %%
df.plot.hist()

# %% [markdown]
# #Nomor 4

# %%
df.plot.scatter(x='math score', y='reading score', c='writing score', colormap='plasma')
